# %%
for collection in "hello my namw is Aqsa":
    print(collection)
# Out:
# h
# e
# l
# l
# o
#
# m
# y
#
# n
# a
# m
# w
#
# i
# s
#
# A
# q
# s
# a

# %%
for values in {2 ,4 ,6 ,8 ,10, 12 ,14, 18 ,19 ,...}:
    print(values)
# Out:
# 2
# Ellipsis
# 4
# 6
# 8
# 10
# 12
# 14
# 18
# 19

# %%
for items in "this is my new house, you can take a look here":
    print(items)
# Out:
# t
# h
# i
# s
#
# i
# s
#
# m
# y
#
# n
# e
# w
#
# h
# o
# u
# s
# e
# ,
#
# y
# o
# u
#
# c
# a
# n
#
# t
# a
# k
# e
#
# a
#
# l
# o
# o
# k
#
# h
# e
# r
# e

# %%
for variable in {"name",'amna',"age",'12'}:
    print(variable)
# Out:
# 12
# age
# amna
# name

# %%
for counter in {2, 3 ,4 ,5 ,6 , "this is the end"}:
    print(counter)
# Out:
# 2
# 3
# 4
# 5
# 6
# this is the end

# %%
for loop in {"data management", "office 786"}:
    print(loop)
# Out:
# data management
# office 786
