# %%
counter = 1
while counter <= 5 :
    print("loop execution",counter)
    counter = counter + 1
# Out:
# loop execution 1
# loop execution 2
# loop execution 3
# loop execution 4
# loop execution 5

# %%
counter = 2
while counter <= 5 :
    print("loop master",counter )
    counter = counter + 1
# Out:
# loop master 2
# loop master 3
# loop master 4
# loop master 5

# %%
num = 1
while num <=5:
    print("loop bang", num)
    num = num + 2
# Out:
# loop bang 1
# loop bang 3
# loop bang 5

# %%
value = 5
while value < 10:
    print('loop result',value)
    value = value + 1
# Out:
# loop result 5
# loop result 6
# loop result 7
# loop result 8
# loop result 9

# %%
counter = 6
while counter <= 11:
    print("the finale",counter)
    counter = counter + 3
# Out:
# the finale 6
# the finale 9

# %%
counter =17
while counter < 20:
    print("hello there is result",counter + 1)
    counter = counter + 1
# Out:
# hello there is result 18
# hello there is result 19
# hello there is result 20

# %%
counter = 50
while counter >=40:
    print("see with your own eyes",'the result is',counter )
    counter = counter - 1
# Out:
# see with your own eyes the result is 50
# see with your own eyes the result is 49
# see with your own eyes the result is 48
# see with your own eyes the result is 47
# see with your own eyes the result is 46
# see with your own eyes the result is 45
# see with your own eyes the result is 44
# see with your own eyes the result is 43
# see with your own eyes the result is 42
# see with your own eyes the result is 41
# see with your own eyes the result is 40

# %%
counter = 20
while counter >= 10 :
    print("hehe result",counter + 1)
    counter = counter - 1
# Out:
# hehe result 21
# hehe result 20
# hehe result 19
# hehe result 18
# hehe result 17
# hehe result 16
# hehe result 15
# hehe result 14
# hehe result 13
# hehe result 12
# hehe result 11
